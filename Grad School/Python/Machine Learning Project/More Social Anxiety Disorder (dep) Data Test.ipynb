# %%
import pandas as pd
from Bio import Entrez, SeqIO
from Bio.Blast import NCBIWWW, NCBIXML
import re
from collections import Counter
import os
from collections import Counter

# %%
ids = []
sequences = []

fastq_file = "dep fastq files/ERR10786170.fastq"

with open(fastq_file, "r") as handle:
    for i, record in enumerate(SeqIO.parse(handle, "fastq")):
        ids.append(record.id)
        sequences.append(record.seq)

df1 = pd.DataFrame({'ID': ids, 'Sequence': sequences})

df1.head()
# Out:
#               ID                                           Sequence
# 0  ERR10786170.1  (G, G, T, T, C, A, A, A, A, T, G, C, C, C, G, ...
# 1  ERR10786170.1  (C, N, C, C, A, T, T, A, C, C, T, T, T, C, G, ...
# 2  ERR10786170.2  (A, G, T, T, T, C, T, T, C, C, A, G, T, T, T, ...
# 3  ERR10786170.2  (T, T, T, T, G, C, A, A, G, T, A, T, T, C, A, ...
# 4  ERR10786170.3  (A, G, C, C, T, G, A, A, C, A, T, C, T, C, C, ...

# %%
genomic_sequence = df1['Sequence'][0]

result_handle = NCBIWWW.qblast("blastn", "nt", genomic_sequence)

blast_records = NCBIXML.parse(result_handle)

for blast_record in blast_records:
    for alignment in blast_record.alignments:
        for hsp in alignment.hsps:
            if hsp.expect < 0.05:
                print("Bacteria Name:", alignment.title)
# Out:
# Bacteria Name: gi|1887004768|gb|CP040530.1| Bacteroides thetaiotaomicron strain DSM 2079 chromosome, complete genome
# Bacteria Name: gi|2323338499|gb|CP083687.1| Bacteroides thetaiotaomicron strain VPI-2808B chromosome
# Bacteria Name: gi|29342101|gb|AE015928.1| Bacteroides thetaiotaomicron VPI-5482, complete genome
# Bacteria Name: gi|2290644306|gb|CP103155.1| Bacteroides thetaiotaomicron strain BFG-576 chromosome, complete genome
# Bacteria Name: gi|2290595203|gb|CP103214.1| Bacteroides thetaiotaomicron strain BFG-498 chromosome, complete genome
# Bacteria Name: gi|2202814649|gb|CP092641.1| Bacteroides thetaiotaomicron strain VPI 5482 chromosome, complete genome
# Bacteria Name: gi|2290770942|gb|CP103238.1| Bacteroides thetaiotaomicron strain BFG-130 chromosome, complete genome
# Bacteria Name: gi|2323328724|gb|CP083685.1| Bacteroides thetaiotaomicron strain VPI-3443 chromosome
# Bacteria Name: gi|2290599450|gb|CP103118.1| Bacteroides thetaiotaomicron strain BFG-510 chromosome, complete genome
# Bacteria Name: gi|2323333535|gb|CP083686.1| Bacteroides thetaiotaomicron strain VPI-3164 chromosome
# Bacteria Name: gi|2323314175|gb|CP083682.1| Bacteroides thetaiotaomicron strain VPI-BT8702 chromosome
# Bacteria Name: gi|2089090361|gb|CP075195.1| Bacteroides thetaiotaomicron strain CL15T119C52 chromosome, complete genome
# Bacteria Name: gi|2290509982|gb|CP103075.1| Bacteroides thetaiotaomicron strain BFG-129 chromosome, complete genome
# Bacteria Name: gi|2098064349|gb|CP081898.1| Bacteroides thetaiotaomicron strain BFG-55 chromosome, complete genome
# Bacteria Name: gi|2589387328|gb|CP134821.1| Bacteroides thetaiotaomicron strain H-2209 chromosome
# Bacteria Name: gi|2323299137|gb|CP083679.1| Bacteroides thetaiotaomicron strain WAL8713 chromosome
# Bacteria Name: gi|2290804814|gb|CP103268.1| Bacteroides thetaiotaomicron strain BFG-478 chromosome, complete genome
# Bacteria Name: gi|2089083332|gb|CP075193.1| Bacteroides thetaiotaomicron strain CL15T12C11 chromosome, complete genome
# Bacteria Name: gi|2669523424|gb|CP143941.1| Bacteroides thetaiotaomicron strain DFI.6.40 chromosome, complete genome
# Bacteria Name: gi|2323308943|gb|CP083681.1| Bacteroides thetaiotaomicron strain VPI-BTDOT2 chromosome
# Bacteria Name: gi|2323319273|gb|CP083683.1| Bacteroides thetaiotaomicron strain VPI-BT7853 chromosome
# Bacteria Name: gi|2293232970|gb|CP103354.1| Bacteroides thetaiotaomicron strain BFG-357 chromosome, complete genome
# Bacteria Name: gi|2290843172|gb|CP103283.1| Bacteroides thetaiotaomicron strain BFG-119 chromosome, complete genome
# Bacteria Name: gi|1808873978|dbj|AP022660.1| Bacteroides thetaiotaomicron F9-2 DNA, nearly complete genome
# Bacteria Name: gi|2323324036|gb|CP083684.1| Bacteroides thetaiotaomicron strain VPI-5482A chromosome
# Bacteria Name: gi|2032930700|gb|CP072242.1| Bacteroides thetaiotaomicron strain CL06T03C18 chromosome, complete genome
# Bacteria Name: gi|2290586404|gb|CP103095.1| Bacteroides thetaiotaomicron strain BFG-148 chromosome, complete genome
# Bacteria Name: gi|2290522746|gb|CP103153.1| Bacteroides thetaiotaomicron strain BFG-484 chromosome, complete genome
# Bacteria Name: gi|2323304150|gb|CP083680.1| Bacteroides thetaiotaomicron strain WAL8669 chromosome
# Bacteria Name: gi|2290796913|gb|CP103247.1| Bacteroides thetaiotaomicron strain BFG-264 chromosome, complete genome
# Bacteria Name: gi|2290531272|gb|CP103072.1| Bacteroides thetaiotaomicron strain BFG-169 chromosome, complete genome
# Bacteria Name: gi|2319002689|gb|CP107194.1| MAG: Bacteroides thetaiotaomicron isolate KR001_HAM_0006 chromosome, complete genome
# Bacteria Name: gi|2589387326|gb|CP134820.1| Bacteroides thetaiotaomicron strain H-2622 chromosome
# Bacteria Name: gi|2293264964|gb|CP103377.1| Bacteroides thetaiotaomicron strain BFG-266 chromosome, complete genome
# Bacteria Name: gi|1947644047|gb|CP065872.1| Bacteroides thetaiotaomicron strain FDAARGOS_935 chromosome
# Bacteria Name: gi|2293271900|gb|CP103375.1| Bacteroides thetaiotaomicron strain BFG-116 chromosome, complete genome
# Bacteria Name: gi|2290539801|gb|CP103077.1| Bacteroides thetaiotaomicron strain BFG-109 chromosome, complete genome
# Bacteria Name: gi|2782643052|gb|CP155529.1| Bacteroides thetaiotaomicron strain 5-290 chromosome, complete genome
# Bacteria Name: gi|2032873895|gb|CP072224.1| Bacteroides thetaiotaomicron strain CL11T00C24 chromosome, complete genome
# Bacteria Name: gi|938475369|gb|CP012937.1| Bacteroides thetaiotaomicron strain 7330 chromosome, complete genome
# Bacteria Name: gi|2290445867|gb|CP103104.1| Bacteroides thetaiotaomicron strain BFG-446 chromosome, complete genome
# Bacteria Name: gi|2293236601|gb|CP103361.1| Bacteroides thetaiotaomicron strain BFG-505 chromosome, complete genome
# Bacteria Name: gi|1828977791|gb|CP050831.1| Bacteroides faecium strain CBA7301 chromosome, complete genome
# Bacteria Name: gi|2290483394|gb|CP103071.1| Bacteroides ovatus strain BFG-464 chromosome
# Bacteria Name: gi|2290562258|gb|CP103080.1| Bacteroides ovatus strain BFG-465 chromosome
# Bacteria Name: gi|1782093953|gb|CP046397.1| Bacteroides ovatus strain FDAARGOS_733 chromosome, complete genome
# Bacteria Name: gi|2722776976|gb|CP134818.1| Bacteroides ovatus strain H-2495 chromosome
# Bacteria Name: gi|2777523482|dbj|AP031410.1| Parabacteroides goldsteinii f09 DNA, complete genome
# Bacteria Name: gi|2023091551|gb|CP064353.1| Parabacteroides goldsteinii strain MTS01 chromosome, complete genome
# Bacteria Name: gi|2023091551|gb|CP064353.1| Parabacteroides goldsteinii strain MTS01 chromosome, complete genome
# Bacteria Name: gi|2784334720|gb|CP165599.1| Parabacteroides goldsteinii strain WXC08 chromosome, complete genome

# %%
fastq_file = "dep fastq files/ERR10786170.fastq"

ids = []
sequences = []

with open(fastq_file, "r") as handle:
    for record in SeqIO.parse(handle, "fastq"):
        ids.append(record.id)
        sequences.append(str(record.seq))

df1 = pd.DataFrame({'ID': ids, 'Sequence': sequences})

genomic_sequence = df1['Sequence'][0][:1000]
result_handle = NCBIWWW.qblast("blastn", "nt", genomic_sequence)
blast_records = NCBIXML.parse(result_handle)

genera = []

for blast_record in blast_records:
    for alignment in blast_record.alignments:
        for hsp in alignment.hsps:
            if hsp.expect < 0.05:
                order_match = re.search(r"Uncultured (\b[A-Z][a-z]+(?:ales|aceae|ota|etes)\b)", alignment.title)
                match = re.search(r"Uncultured ([A-Z][a-z]+) sp", alignment.title) 
                general_match = re.search(r"\b([A-Z][a-z]+)\b(?!\s*(bacterium|organism|RNA|DNA))", alignment.title)
                unknown_match = re.search(r"Uncultured (bacterium|organism)", alignment.title, re.IGNORECASE)
                rumen_match = re.search(r"Uncultured rumen bacterium", alignment.title, re.IGNORECASE)

                
                if order_match:
                    genera.append(order_match.group(1))
                elif match:
                    genera.append(match.group(1))
                elif rumen_match:
                    genera.append("Rumen Bacterium")  # Custom category for clarity
                elif general_match:
                    genera.append(general_match.group(1))
                elif unknown_match:
                    genera.append("Uncultured Organism")



genus_counts = Counter(genera)

df = pd.DataFrame(genus_counts.items(), columns=['Genus', 'Count'])
df['Relative Abundance'] = df['Count'] / df['Count'].sum()
df = df.drop(columns=['Count'])
df = df.sort_values(by='Relative Abundance', ascending=False)

df = df.T
df.insert(0, 'File Name', os.path.basename(fastq_file))
df = df.reset_index(drop=True)
df.columns = df.iloc[0] 
df = df.drop(0)
df = df.rename(columns={os.path.basename(fastq_file): 'File Name'})

df
# Out:
# 0          File Name Bacteroides Parabacteroides
# 1  ERR10786170.fastq    0.921569        0.078431

# %%
df.columns
# Out:
# Index(['File Name', 'Enterocloster', 'Ruminococcus', 'Eubacterium',
#        'Caproicibacterium', 'Agathobacter', 'Dorea', 'Blautia',
#        'Eisenbergiella', 'Roseburia', 'Clostridiales', 'Anaerocolumna',
#        'Lachnoclostridium', 'Marvinbryantia', 'Caudoviricetes',
#        'Rossellomorea', 'Bacteriophage', 'Candidatus', 'Bacillota',
#        'Domibacillus', 'Caproicibacter', 'Caproiciproducens'],
#       dtype='object', name=0)

# %%
# title = "Bacteria Name: gi|2025053910|dbj|AP023418.1| Vescimonas coprocola MM50 DNA, complete genome"

# match = re.search(r"\b([A-Z][a-z]+[a-zA-Z]*)\b(?!.*bacterium)(?!.*organism)(?!.*RNA)(?!.*DNA)", title)

# print("Match:", match.group(1) if match else "No match")

# %%
# title = "gi|2025053910|dbj|AP023418.1| Vescimonas coprocola MM50 DNA, complete genome"

# # Perform regex searches
# order_match = re.search(r"Uncultured (\b[A-Z][a-z]+(?:ales|aceae|ota|etes)\b)", title)
# match = re.search(r"Uncultured ([A-Z][a-z]+) sp", title)
# rumen_match = re.search(r"Uncultured rumen bacterium", title, re.IGNORECASE)
# unknown_match = re.search(r"Uncultured (bacterium|organism)", title, re.IGNORECASE)
# general_match = re.search(r"\b([A-Z][a-z]+)\b(?!\s*(bacterium|organism|RNA|DNA))", title)

# # Initialize the genera list
# genera = []

# # Check matches and append accordingly
# if order_match:
#     print("Order match found:", order_match.group(1))
#     genera.append(order_match.group(1))
# elif match:
#     print("Species match found:", match.group(1))
#     genera.append(match.group(1))
# elif rumen_match:
#     print("Rumen match found")
#     genera.append("Rumen Bacterium")
# elif unknown_match:
#     print("Unknown match found")
#     genera.append("Uncultured Organism")
# elif general_match:
#     print("General match found:", general_match.group(1))
#     genera.append(general_match.group(1))
# else:
#     print("No match found for:", title)

# # Print results
# print("Final genera list:", genera)

# %%
# title = "gi|2025053910|dbj|AP023418.1| Vescimonas coprocola MM50 DNA, complete genome"

# # Simplified regex to check for "Vescimonas"
# match = re.search(r"\b([A-Z][a-z]+)\b", title)

# if match:
#     print("Match found:", match.group(1))
# else:
#     print("No match found")
