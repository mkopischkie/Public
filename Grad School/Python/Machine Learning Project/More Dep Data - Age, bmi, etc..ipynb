# %%
import pandas as pd

# %%
df = pd.read_csv('SraRunTable_dep.csv')
df
# Out:
#             Run Assay Type  AvgSpotLen       Bases  BioProject  \
# 0   ERR10786160        WGS         292   381141888  PRJEB58864
# 1   ERR10786161        WGS         292   375914378  PRJEB58864
# 2   ERR10786162        WGS         293   378364978  PRJEB58864
# 3   ERR10786163        WGS         292   367605301  PRJEB58864
# 4   ERR10786164        WGS         292   352292935  PRJEB58864
# 5   ERR10786165        WGS         292   345748323  PRJEB58864
# 6   ERR10786166        WGS         293   349156577  PRJEB58864
# 7   ERR10786167        WGS         293   336145936  PRJEB58864
# 8   ERR10786168        WGS         293   419973500  PRJEB58864
# 9   ERR10786169        WGS         293   413323203  PRJEB58864
# 10  ERR10786170        WGS         293   418406777  PRJEB58864
# 11  ERR10786171        WGS         293   402782069  PRJEB58864
# 12  ERR10786172        WGS         289   487253296  PRJEB58864
# 13  ERR10786173        WGS         290   480852540  PRJEB58864
# ...

# %%
df.columns
# Out:
# Index(['Run', 'Assay Type', 'AvgSpotLen', 'Bases', 'BioProject', 'BioSample',
#        'broad-scale_environmental_context', 'Bytes', 'Center Name',
#        'Collection_Date', 'common_name', 'Consent', 'DATASTORE filetype',
#        'DATASTORE provider', 'DATASTORE region', 'ENA-FIRST-PUBLIC (run)',
#        'ENA_first_public', 'ENA-LAST-UPDATE (run)', 'ENA-LAST-UPDATE',
#        'environmental_medium', 'Experiment', 'external_id',
#        'geo_loc_name_country', 'geo_loc_name_country_continent',
#        'geographic_location_(country_and/or_sea)',
#        'geographic_location_(latitude)', 'geographic_location_(longitude)',
#        'INSDC_center_name', 'INSDC_first_public', 'INSDC_last_update',
#        'INSDC_status', 'Instrument', 'Library Name', 'LibraryLayout',
#        'LibrarySelection', 'LibrarySource', 'local_environmental_context',
#        'Organism', 'Platform', 'project_name', 'ReleaseDate', 'create_date',
# ...
