# %%
import pandas as pd

# %%
df = pd.read_csv('SraRunTable_sch.csv')
df
# Out:
#             Run         AGE Assay Type  AvgSpotLen     Bases  \
# 0   SRR18576085  Not Public   AMPLICON         493  31766455
# 1   SRR18576086  Not Public   AMPLICON         494  29964558
# 2   SRR18576087  Not Public   AMPLICON         495  50834520
# 3   SRR18576088  Not Public   AMPLICON         492  46181580
# 4   SRR18576089  Not Public   AMPLICON         493  42934877
# 5   SRR18576090  Not Public   AMPLICON         494  52231608
# 6   SRR18576091  Not Public   AMPLICON         495  49044600
# 7   SRR18576092  Not Public   AMPLICON         494  34854664
# 8   SRR18576093  Not Public   AMPLICON         495  34473285
# 9   SRR18576094  Not Public   AMPLICON         492  33150468
# 10  SRR18576095  Not Public   AMPLICON         493  34434571
# 11  SRR18576096  Not Public   AMPLICON         494  40012518
# 12  SRR18576097  Not Public   AMPLICON         495  35977095
# 13  SRR18576098  Not Public   AMPLICON         494  38412946
# ...

# %%
df.columns
# Out:
# Index(['Run', 'AGE', 'Assay Type', 'AvgSpotLen', 'Bases',
#        'BIOMATERIAL_PROVIDER', 'BioProject', 'BioSample', 'BioSampleModel',
#        'Bytes', 'Center Name', 'Collection_Date', 'Consent',
#        'DATASTORE filetype', 'DATASTORE provider', 'DATASTORE region',
#        'Experiment', 'geo_loc_name_country', 'geo_loc_name_country_continent',
#        'geo_loc_name', 'HOST', 'Instrument', 'isolate', 'lat_lon',
#        'Library Name', 'LibraryLayout', 'LibrarySelection', 'LibrarySource',
#        'Organism', 'Platform', 'ReleaseDate', 'create_date', 'version',
#        'Sample Name', 'sex', 'SRA Study', 'tissue'],
#       dtype='object')

# %%
df = df.drop(['AGE', 'Assay Type', 'AvgSpotLen', 'Bases',
       'BIOMATERIAL_PROVIDER', 'BioProject', 'BioSample', 'BioSampleModel',
       'Bytes', 'Center Name', 'Collection_Date', 'Consent',
       'DATASTORE filetype', 'DATASTORE provider', 'DATASTORE region',
       'Experiment', 'geo_loc_name_country_continent',
       'geo_loc_name_country', 'geo_loc_name', 'HOST', 'Instrument', 'isolate', 'lat_lon',
       'Library Name', 'LibraryLayout', 'LibrarySelection', 'LibrarySource',
       'Organism', 'Platform', 'ReleaseDate', 'create_date', 'version',
       'Sample Name', 'SRA Study', 'tissue'], axis=1)

# %%
df
# Out:
#             Run   sex
# 0   SRR18576085  male
# 1   SRR18576086  male
# 2   SRR18576087  male
# 3   SRR18576088  male
# 4   SRR18576089  male
# 5   SRR18576090  male
# 6   SRR18576091  male
# 7   SRR18576092  male
# 8   SRR18576093  male
# 9   SRR18576094  male
# 10  SRR18576095  male
# 11  SRR18576096  male
# 12  SRR18576097  male
# 13  SRR18576098  male
# 14  SRR18576099  male
# 15  SRR18576100  male
# 16  SRR18576101  male
# 17  SRR18576102  male
# 18  SRR18576103  male
# 19  SRR18576104  male
# 20  SRR18576105  male
# 21  SRR18576106  male
# 22  SRR18576107  male
# 23  SRR18576108  male
# 24  SRR18576109  male
# 25  SRR18576110  male
# 26  SRR18576111  male
# 27  SRR18576112  male
# 28  SRR18576113  male
# 29  SRR18576114  male
# 30  SRR18576115  male
# 31  SRR18576116  male
# 32  SRR18576117  male
# 33  SRR18576118  male
# 34  SRR18576119  male
# 35  SRR18576120  male
# 36  SRR18576121  male
# 37  SRR18576122  male
# 38  SRR18576123  male
# 39  SRR18576124  male
# ...

# %%
df.to_csv('associated_sch_data.csv')
